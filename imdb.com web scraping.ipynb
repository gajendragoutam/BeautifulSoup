# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
#  Q 1 ) Write a python program to display IMDB’s Top rated 100 Indian movies’ data
#        https://www.imdb.com/list/ls056092300/ (i.e. name, rating, year ofrelease) and make data frame.

# %%
web = requests.get("https://www.imdb.com/list/ls056092300/ ")
web
# Response is [ 404 ]
# Out:
# <Response [404]>

# %%
#  Q  2) Write a python program to scrape details of all the posts from https://www.patreon.com/coreyms .Scrape the
#       heading, date, content and the likes for the video from the link for the youtube video from the post.

# %%
web = requests.get ( ' https://www.patreon.com/coreyms ')
web
# Respose is [ 404 ]
# Out:
# <Response [404]>

# %%
# Q 4)  Write a python program to scrape first 10 product details which include product name , price , Image URL from
#        https://www.bewakoof.com/bestseller?sort=popular .

# %%
url = ('https://www.bewakoof.com/bestseller?sort=popular')
web = requests.get(url)
soup = BeautifulSoup(web.text, 'html.parser')

# %%
product = soup.find_all('div', class_='productCardBox', limit=10)

# %%
product_details = []
for pct in product:
    name = pct.find('h3').text.strip()if pct.find('h3') else "No Name"
    price = pct.find('b').text.strip()if pct.find('b') else "No Price"
    image = pct.find('img')['src']if pct.find('img') else "No Image URL"

    product_details.append({
        'name': name,
        'price': price,
        'image_url': image
     })

# %%
for index in range(len(product_details)):
    product = product_details[index]
    print(f"Product {index + 1}:")
    print(f"Name: {product['name']}")
    print(f"Price: {product['price']}")
    print(f"Image URL: {product['image_url']}")
    print()
# Out:
# Product 1:
# Name: Bewakoof®
# Price: ₹1099
# Image URL: https://images.bewakoof.com/t640/men-s-brown-oversized-cargo-pants-629284-1714978158-1.jpg
#
# Product 2:
# Name: bewakoof x star wars
# Price: ₹639
# Image URL: https://images.bewakoof.com/t640/men-s-black-storm-trooper-graphic-printed-oversized-t-shirt-637004-1717579157-1.jpg
#
# Product 3:
# Name: Bewakoof®
# Price: ₹629
# Image URL: https://images.bewakoof.com/t640/men-s-red-hunter-graphic-printed-oversized-t-shirt-636819-1716287798-1.jpg
#
# Product 4:
# Name: Bewakoof®
# Price: ₹549
# Image URL: https://images.bewakoof.com/t640/women-s-orange-skool-graphic-printed-boyfriend-t-shirt-635956-1711605320-1.jpg
#
# Product 5:
# Name: Bewakoof®
# Price: ₹1069
# Image URL: https://images.bewakoof.com/t640/men-s-grey-oversized-parachute-pants-628721-1706071730-1.jpg
#
# Product 6:
# Name: Bewakoof Air® 1.0
# Price: ₹969
# Image URL: https://images.bewakoof.com/t640/men-s-black-oversized-cargo-joggers-552880-1710766583-1.jpg
#
# ...

# %%
# Q 5 '' Please visit https://www.cnbc.com/world/?region=world and scrap-
#   a) headings
#   b) date
#  c) News link

# %%
url = "https://www.cnbc.com/world/?region=world"
response = requests.get(url)

# %%
soup = BeautifulSoup(response.content, "html.parser")
articles = soup.find_all('div', class_='Card-titleContainer')

# %%
for article in articles:
        title_f= article.find('a', class_='Card-title')
        title = title_f.get_text(strip=True)
        link = title_f["href"]
        
        print(f"Title: {title}")
        print(f"link: {link}")
        print( "date is not available")
        print()
# Out:
# Title: Stocks making the biggest moves premarket: La-Z-Boy, NextEra Energy, Kroger, Lennar and more
# link: https://www.cnbc.com/2024/06/18/stocks-making-the-biggest-moves-premarket-lzb-nee-kr-len-and-more.html
# date is not available
#
# Title: May retail sales rise 0.1%, weaker than expected
# link: https://www.cnbc.com/2024/06/18/retail-sales-report-may-2024-may-retail-sales-rise-0point1percent.html
# date is not available
#
# Title: S&P 500 rises slightly as investors try to shake off weak retail sales data: Live updates
# link: https://www.cnbc.com/2024/06/17/stock-market-today-live-updates.html
# date is not available
#
# Title: Millionaires are abandoning the UK in their droves, new research shows
# link: https://www.cnbc.com/2024/06/18/millionaires-are-abandoning-the-uk-in-their-droves-new-research-shows.html
# date is not available
#
# Title: Britain's Labour Party pledges 'wealth creation' as it targets landslide election victory
# ...

# %%
# Q 6 ) Please visit https://www.keaipublishing.com/en/journals/artificial-intelligence-in-agriculture/most-downloaded articles/ and scrap
#  a) Paper title
#  b) date
#  c) Author

# %%
url = ("https://www.keaipublishing.com/en/journals/artificial-intelligence-in-agriculture/most-downloaded-articles/")
print(url)
# Out:
# https://www.keaipublishing.com/en/journals/artificial-intelligence-in-agriculture/most-downloaded-articles/

# %%
web1 = requests.get(url)

# %%
soup= BeautifulSoup(web1.text,'html.parser')

# %%
ar = soup.find_all('div', class_="article-listing")

# %%
    data = []

    for article in ar:
        title = article.find('h2', class_="article-title").get_text(strip=True)
        date = article.find('p', class_="article-date").get_text(strip=True)
        author = article.find('p', class_='article-authors').get_text(strip=True)
        
        data.append({
            "title": title,
            "date": date,
            "author":author})
        

        df = pd.DataFrame(data)
        df
        
        
        
       # print(f"Title: {title}")
       # print(f"Date: {date}")
       # print(f"Author: {author}")
        #print()
      #  print()

# %%
df
# Out:
#                                                 title            date  \
# 0   Implementation of artificial intelligence in a...            2020
# 1               Review of agricultural IoT technology            2022
# 2   A comprehensive review on automation in agricu...       June 2019
# 3   Automation and digitization of agriculture usi...            2021
# 4   Applications of electronic nose (e-nose) and e...            2020
# 5   Deep learning based computer vision approaches...            2022
# 6             Fruit ripeness classification: A survey      March 2023
# 7   A review of imaging techniques for plant disea...            2020
# 8   Transfer Learning for Multi-Crop Leaf Disease ...            2022
# 9   How artificial intelligence uses to achieve th...       June 2023
# 10  DeepRice: A deep learning and deep feature bas...      March 2024
# 11  Using an improved lightweight YOLOv8 model for...      March 2024
# ...
